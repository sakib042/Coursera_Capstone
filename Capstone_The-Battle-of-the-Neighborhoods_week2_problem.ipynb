# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 1)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In this project we will try to find an optimal location for a restaurant. Specifically, this report will be targeted to stakeholders interested in opening an **Coffee Shop** in **Stockholm**, Sweden.
#
# Since there are lots of restaurants in Stockholm we will try to detect **locations that are not already crowded with restaurants**. We are also particularly interested in **areas with no coffee shop in vicinity**. We would also prefer locations **as close to city center as possible**, assuming that first two conditions are met.
#
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
# * number of existing coffee shop in the neighborhood (including restaurant offer coffee)
# * number of and distance to other coffee shop in the neighborhood, if any
# * distance of neighborhood from city center
#
# We decided to use regularly spaced grid of locations, centered around city center, to define our neighborhoods.
#
# Following data sources will be needed to extract/generate the required information:
# * centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained using **Google Maps API reverse geocoding**
# * number of coffee shop and their type and location in every neighborhood will be obtained using **Foursquare API**
# * coordinate of Dhaka center will be obtained using **Google Maps API geocoding**

# %% [markdown]
# ### Neighborhood Candidates
#
# Let's create latitude & longitude coordinates for centroids of our candidate neighborhoods. We will create a grid of cells covering our area of interest which is aprox. 12x12 killometers centered around Berlin city center.
#
# Let's first find the latitude & longitude of Berlin city center, using specific, well known address and Google Maps geocoding API.

# %%
#!pip install folium
import folium
#!pip install geopy
from geopy.geocoders import Nominatim
#!pip install shapely
#import shapely.geometry
#!pip install pyproj
import pyproj
import math
import json # library to handle JSON files
import requests
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
#import beautiful soup
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
print('library added')
# Out:
# library added

# %%
address = 'Stockholm, Sweden'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
stockholm_center = [latitude, longitude]
print('The geograpical coordinate of ', address ,'are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of  Stockholm, Sweden are 59.3251172, 18.0710935.

# %% [markdown]
# Now let's create a grid of area candidates, equaly spaced, centered around city center and within ~6km from Stockholm. Our neighborhoods will be defined as circular areas with a radius of 300 meters, so our neighborhood centers will be 600 meters apart.
#
# To accurately calculate distances we need to create our grid of locations in Cartesian 2D coordinate system which allows us to calculate distances in meters (not in latitude/longitude degrees). Then we'll project those coordinates back to latitude/longitude degrees to be shown on Folium map. So let's create functions to convert between WGS84 spherical coordinate system (latitude/longitude degrees) and UTM Cartesian coordinate system (X/Y coordinates in  meters).

# %%
def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

print('Coordinate transformation check')
print('-------------------------------')
print('Stockholm center longitude={}, latitude={}'.format(stockholm_center[1], stockholm_center[0]))
x, y = lonlat_to_xy(stockholm_center[1], stockholm_center[0])
print('Stockholm center UTM X={}, Y={}'.format(x, y))
lo, la = xy_to_lonlat(x, y)
print('Stockholm center longitude={}, latitude={}'.format(lo, la))
# Out:
# Coordinate transformation check
# -------------------------------
# Stockholm center longitude=18.0710935, latitude=59.3251172
# Stockholm center UTM X=674735.1349179444, Y=6580284.089114029
# Stockholm center longitude=18.0710935, latitude=59.3251172

# %%
stockholm_center_x, stockholm_center_y = lonlat_to_xy(stockholm_center[1], stockholm_center[0]) # City center in Cartesian coordinates

k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min = stockholm_center_x - 6000
x_step = 600
y_min = stockholm_center_y - 6000 - (int(21/k)*k*600 - 12000)/2
y_step = 600 * k 

latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []
for i in range(0, int(21/k)):
    y = y_min + i * y_step
    x_offset = 300 if i%2==0 else 0
    for j in range(0, 21):
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(stockholm_center_x, stockholm_center_y, x, y)
        if (distance_from_center <= 6001):
            lon, lat = xy_to_lonlat(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)

print(len(latitudes), 'candidate neighborhood centers generated.')
# Out:
# 364 candidate neighborhood centers generated.

# %% [markdown]
# Let's create a **hexagonal grid of cells**: we offset every other row, and adjust vertical row spacing so that **every cell center is equally distant from all it's neighbors**.

# %%
map_stockholm = folium.Map(location=stockholm_center, zoom_start=13)
folium.Marker(stockholm_center, popup='Stockholm').add_to(map_stockholm)
for lat, lon in zip(latitudes, longitudes):
    #folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_berlin) 
    folium.Circle([lat, lon], radius=300, color='blue', fill=False).add_to(map_stockholm)
    #folium.Marker([lat, lon]).add_to(map_berlin)
map_stockholm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's visualize the data we have so far: city center location and candidate neighborhood centers:

# %% [markdown]
# OK, we now have the coordinates of centers of neighborhoods/areas to be evaluated, equally spaced (distance from every point to it's neighbors is exactly the same) and within ~6km from Stortorget, Stockholm.
#
# Let's now use Google Maps API to get approximate addresses of those locations.

# %% [markdown]
# #### Entering in our information into the Foursquare API to access it.

# %%
CLIENT_ID = 'JA2RLBI4IPPSFTWAVNIXIOLLUVQCOHIB4AV0ZTEBSLZGE0GI' # your Foursquare ID
CLIENT_SECRET = 'IUE4XAZ1BIFVBZDALGNDY4HDW3IU1EDX4NAGN4F3OW4VWAE5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JA2RLBI4IPPSFTWAVNIXIOLLUVQCOHIB4AV0ZTEBSLZGE0GI
# CLIENT_SECRET:IUE4XAZ1BIFVBZDALGNDY4HDW3IU1EDX4NAGN4F3OW4VWAE5

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=JA2RLBI4IPPSFTWAVNIXIOLLUVQCOHIB4AV0ZTEBSLZGE0GI&client_secret=IUE4XAZ1BIFVBZDALGNDY4HDW3IU1EDX4NAGN4F3OW4VWAE5&v=20180605&ll=59.3251172,18.0710935&radius=500&limit=100'

# %% [markdown]
# #### Result from Foursquare

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d42e201342adf002bb577e3'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Storkyrkan',
#   'headerFullLocation': 'Storkyrkan, Stockholm',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 102,
#   'suggestedBounds': {'ne': {'lat': 59.3296172045, 'lng': 18.079897699230337},
#    'sw': {'lat': 59.3206171955, 'lng': 18.062289300769663}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b06fe89f964a520fef422e3',
#        'name': 'Science Fiction Bokhandeln',
#        'location': {'address': 'Västerlånggatan 48',
#         'crossStreet': 'Gamla Stan',
#         'lat': 59.32404679408319,
#         'lng': 18.070682162632647,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32404679408319,
#           'lng': 18.070682162632647}],
#         'distance': 121,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Västerlånggatan 48 (Gamla Stan)',
#          '111 29 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b06fe89f964a520fef422e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51434b65e4b00cf8d47795f1',
#        'name': 'Tweed',
#        'location': {'address': 'Lilla Nygatan 5',
#         'lat': 59.3244713,
#         'lng': 18.0676958,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.3244713,
#           'lng': 18.0676958}],
#         'distance': 205,
#         'postalCode': '111 28',
#         'cc': 'SE',
#         'neighborhood': 'Storkyrkan',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Lilla Nygatan 5',
#          '111 28 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51434b65e4b00cf8d47795f1-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0e3607f964a520fa5523e3',
#        'name': 'Stortorget',
#        'location': {'address': 'Stortorget',
#         'crossStreet': 'Gamla Stan',
#         'lat': 59.324973,
#         'lng': 18.070727,
#         'distance': 26,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stortorget (Gamla Stan)',
#          '111 29 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0e3607f964a520fa5523e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '549447fb498ed7d33f190dc2',
#        'name': 'Barrels Burgers & Beer',
#        'location': {'address': 'Stora Nygatan 20',
#         'crossStreet': 'Yxsmedsgränd',
#         'lat': 59.324685223744616,
#         'lng': 18.068512685688464,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.324685223744616,
#           'lng': 18.068512685688464}],
#         'distance': 154,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora Nygatan 20 (Yxsmedsgränd)',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '126348335'}},
#       'referralId': 'e-0-549447fb498ed7d33f190dc2-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8596c602d59e1a9afa5d5e',
#        'name': 'Stockholms Gästabud',
#        'location': {'address': 'Österlånggatan 7',
#         'lat': 59.32556915886631,
#         'lng': 18.073990898338362,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32556915886631,
#           'lng': 18.073990898338362}],
#         'distance': 172,
#         'postalCode': '111 31',
#         'cc': 'SE',
#         'neighborhood': 'Storkyrkan',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Österlånggatan 7',
#          '111 31 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8596c602d59e1a9afa5d5e-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '534d0a34498ef782062ac89c',
#        'name': 'Tradition',
#        'location': {'address': 'Österlånggatan 1',
#         'lat': 59.32594,
#         'lng': 18.07371,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32594,
#           'lng': 18.07371}],
#         'distance': 174,
#         'postalCode': '111 31',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Österlånggatan 1',
#          '111 31 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1c6941735',
#          'name': 'Scandinavian Restaurant',
#          'pluralName': 'Scandinavian Restaurants',
#          'shortName': 'Scandinavian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-534d0a34498ef782062ac89c-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514c0868e4b07a3d6af2fca3',
#        'name': 'Corner Club',
#        'location': {'address': 'Lilla Nygatan 16',
#         'lat': 59.323342388892044,
#         'lng': 18.069430517409064,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.323342388892044,
#           'lng': 18.069430517409064}],
#         'distance': 218,
#         'postalCode': '111 28',
#         'cc': 'SE',
#         'neighborhood': 'Storkyrkan',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Lilla Nygatan 16',
#          '111 28 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-514c0868e4b07a3d6af2fca3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '522784bb11d2164a04286219',
#        'name': 'The Burgundy',
#        'location': {'address': 'Yxsmedsgränd 12',
#         'lat': 59.3244342959212,
#         'lng': 18.06816127441035,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.3244342959212,
#           'lng': 18.06816127441035}],
#         'distance': 183,
#         'postalCode': '111 28',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Yxsmedsgränd 12',
#          '111 28 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-522784bb11d2164a04286219-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba0c261f964a520a77b37e3',
#        'name': 'Slingerbulten',
#        'location': {'address': 'Stora Nygatan 24',
#         'lat': 59.32437575389649,
#         'lng': 18.068967398469628,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32437575389649,
#           'lng': 18.068967398469628}],
#         'distance': 146,
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora Nygatan 24', 'Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1c6941735',
#          'name': 'Scandinavian Restaurant',
#          'pluralName': 'Scandinavian Restaurants',
#          'shortName': 'Scandinavian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba0c261f964a520a77b37e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '537f7e60498e54e075c24907',
#        'name': 'The Hairy Pig Deli',
#        'location': {'address': 'Österlånggatan 9',
#         'lat': 59.32555532955525,
#         'lng': 18.07395817425968,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32555532955525,
#           'lng': 18.07395817425968}],
#         'distance': 169,
#         'postalCode': '111 31',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Österlånggatan 9',
#          '111 31 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-537f7e60498e54e075c24907-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9a5e8ff964a52072af35e3',
#        'name': '19 Glas Bar & Matsal',
#        'location': {'address': 'Stora nygatan 19',
#         'lat': 59.324633,
#         'lng': 18.068670200000042,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.324633,
#           'lng': 18.068670200000042}],
#         'distance': 147,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora nygatan 19',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9a5e8ff964a52072af35e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdaebf964a520ae5921e3',
#        'name': 'Wirströms Pub',
#        'location': {'address': 'Stora Nygatan 13',
#         'crossStreet': 'Gåsgränd',
#         'lat': 59.324897170328015,
#         'lng': 18.06819160116579,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.324897170328015,
#           'lng': 18.06819160116579}],
#         'distance': 166,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'neighborhood': 'Gamla s',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora Nygatan 13 (Gåsgränd)',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '35076385'}},
#       'referralId': 'e-0-4adcdaebf964a520ae5921e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdaedf964a5207c5a21e3',
#        'name': 'Stampen',
#        'location': {'address': 'Stora Nygatan 5',
#         'lat': 59.325298000157154,
#         'lng': 18.067555187183842,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.325298000157154,
#           'lng': 18.067555187183842}],
#         'distance': 201,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora Nygatan 5',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1e7931735',
#          'name': 'Jazz Club',
#          'pluralName': 'Jazz Clubs',
#          'shortName': 'Jazz Club',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcdaedf964a5207c5a21e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53a92582498eacb3853e0379',
#        'name': 'Fabrique Stenugnsbageri',
#        'location': {'address': 'Lilla Nygatan 12',
#         'crossStreet': 'Schönfeldts Gränd',
#         'lat': 59.32362471559476,
#         'lng': 18.068699964361887,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32362471559476,
#           'lng': 18.068699964361887}],
#         'distance': 214,
#         'postalCode': '111 28',
#         'cc': 'SE',
#         'neighborhood': 'Gamla Stan, Stockholm',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Lilla Nygatan 12 (Schönfeldts Gränd)',
#          '111 28 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53a92582498eacb3853e0379-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51ccb742498e64f625f8ce57',
#        'name': 'Pharmarium',
#        'location': {'address': 'Stortorget 7',
#         'lat': 59.324851,
#         'lng': 18.070891,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.324851,
#           'lng': 18.070891}],
#         'distance': 31,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stortorget 7', '111 29 Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51ccb742498e64f625f8ce57-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcaf04afb84c9b624ee1d3e',
#        'name': 'Comics Heaven',
#        'location': {'address': 'Stora Nygatan 23',
#         'crossStreet': 'Kåkbrinken',
#         'lat': 59.32436917834956,
#         'lng': 18.069033327341696,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32436917834956,
#           'lng': 18.069033327341696}],
#         'distance': 143,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora Nygatan 23 (Kåkbrinken)',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b18',
#          'name': 'Comic Shop',
#          'pluralName': 'Comic Shops',
#          'shortName': 'Comic Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/comic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '87818895'}},
#       'referralId': 'e-0-4bcaf04afb84c9b624ee1d3e-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdaeef964a520c95a21e3',
#        'name': 'Kungliga Slottet (Kungliga slottet)',
#        'location': {'address': 'Slottsbacken',
#         'crossStreet': 'Gamla Stan',
#         'lat': 59.32635297037483,
#         'lng': 18.071139541044186,
#         'distance': 137,
#         'postalCode': '111 30',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Slottsbacken (Gamla Stan)',
#          '111 30 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a14',
#          'name': 'Palace',
#          'pluralName': 'Palaces',
#          'shortName': 'Palace',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcdaeef964a520c95a21e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2dc7d5e307d13ad8510eda',
#        'name': 'Sound Pollution AB',
#        'location': {'address': 'Stora Nygatan 18',
#         'lat': 59.324747168258455,
#         'lng': 18.06845858243293,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.324747168258455,
#           'lng': 18.06845858243293}],
#         'distance': 155,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora Nygatan 18',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d10d951735',
#          'name': 'Record Shop',
#          'pluralName': 'Record Shops',
#          'shortName': 'Record Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/record_shop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2dc7d5e307d13ad8510eda-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5729f110498e722233305953',
#        'name': 'Matgatan 22',
#        'location': {'address': 'Stora Nygatan 22',
#         'lat': 59.324454,
#         'lng': 18.068671,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.324454,
#           'lng': 18.068671}],
#         'distance': 156,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora Nygatan 22',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a04',
#          'name': 'Polish Restaurant',
#          'pluralName': 'Polish Restaurants',
#          'shortName': 'Polish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5729f110498e722233305953-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c78322f93ef236a9772ab0f',
#        'name': 'Kryp In',
#        'location': {'address': 'Prästgatan 17',
#         'lat': 59.32469405171839,
#         'lng': 18.0700589994161,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32469405171839,
#           'lng': 18.0700589994161}],
#         'distance': 75,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Prästgatan 17', '111 29 Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1c6941735',
#          'name': 'Scandinavian Restaurant',
#          'pluralName': 'Scandinavian Restaurants',
#          'shortName': 'Scandinavian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c78322f93ef236a9772ab0f-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '550867d7498e86f0d8c9a61d',
#        'name': "Geronimo's FGT",
#        'location': {'address': 'Stora Nygatan 5',
#         'lat': 59.32519758596976,
#         'lng': 18.067725269541082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32519758596976,
#           'lng': 18.067725269541082}],
#         'distance': 191,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora Nygatan 5',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-550867d7498e86f0d8c9a61d-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c0cc79e4b0a80fdc3460df',
#        'name': 'Gaston - Wine Exploring',
#        'location': {'address': 'Mälartorget 15',
#         'lat': 59.323206,
#         'lng': 18.06864,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.323206,
#           'lng': 18.06864}],
#         'distance': 254,
#         'postalCode': '111 28',
#         'cc': 'SE',
#         'neighborhood': 'Gamla stan',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Mälartorget 15', '111 28 Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c0cc79e4b0a80fdc3460df-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ece875cb634dd298f5ea304',
#        'name': 'AIFUR | krog & bar',
#        'location': {'address': 'Västerlånggatan 68b',
#         'lat': 59.32309737228725,
#         'lng': 18.071992987666622,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32309737228725,
#           'lng': 18.071992987666622}],
#         'distance': 230,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Västerlånggatan 68b',
#          '111 29 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1c6941735',
#          'name': 'Scandinavian Restaurant',
#          'pluralName': 'Scandinavian Restaurants',
#          'shortName': 'Scandinavian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ece875cb634dd298f5ea304-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc28371887770a6be00accd',
#        'name': 'Caffellini',
#        'location': {'address': 'Västerlånggatan',
#         'lat': 59.32356,
#         'lng': 18.071373,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32356,
#           'lng': 18.071373}],
#         'distance': 174,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Västerlånggatan',
#          '111 29 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc28371887770a6be00accd-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b63079df964a520945e2ae3',
#        'name': 'Ardbeg Embassy',
#        'location': {'address': 'Västerlånggatan 68',
#         'crossStreet': 'Torgdragargränd',
#         'lat': 59.32317024450012,
#         'lng': 18.071903771657055,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32317024450012,
#           'lng': 18.071903771657055}],
#         'distance': 221,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Västerlånggatan 68 (Torgdragargränd)',
#          '111 29 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1c6941735',
#          'name': 'Scandinavian Restaurant',
#          'pluralName': 'Scandinavian Restaurants',
#          'shortName': 'Scandinavian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b63079df964a520945e2ae3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c0cbb9e4b01109e244886c',
#        'name': 'The Flying Elk',
#        'location': {'address': 'Mälartorget 15',
#         'crossStreet': 'Tyska brinken',
#         'lat': 59.323085,
#         'lng': 18.068833,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.323085,
#           'lng': 18.068833}],
#         'distance': 260,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Mälartorget 15 (Tyska brinken)',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c0cbb9e4b01109e244886c-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53186d00498ec3e4b9002cd2',
#        'name': 'Royal Apartments',
#        'location': {'lat': 59.326226112384795,
#         'lng': 18.07187223983223,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.326226112384795,
#           'lng': 18.07187223983223}],
#         'distance': 131,
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stockholm', 'Sverige']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53186d00498ec3e4b9002cd2-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58c90efcd243323eaf526efb',
#        'name': 'Kagges',
#        'location': {'address': 'Lilla Nygatan 21',
#         'lat': 59.32337090557411,
#         'lng': 18.069441318511963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32337090557411,
#           'lng': 18.069441318511963}],
#         'distance': 215,
#         'postalCode': '111 28',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Lilla Nygatan 21',
#          '111 28 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1c6941735',
#          'name': 'Scandinavian Restaurant',
#          'pluralName': 'Scandinavian Restaurants',
#          'shortName': 'Scandinavian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58c90efcd243323eaf526efb-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '583875a96d632566864f820c',
#        'name': 'The Hairy Pig Restaurant',
#        'location': {'address': 'Lilla Nygatan 13',
#         'lat': 59.32373844474987,
#         'lng': 18.068741758655676,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32373844474987,
#           'lng': 18.068741758655676}],
#         'distance': 203,
#         'postalCode': '111 28',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Lilla Nygatan 13',
#          '111 28 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '56aa371be4b08b9a8d573538',
#          'name': 'Theme Restaurant',
#          'pluralName': 'Theme Restaurants',
#          'shortName': 'Theme Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-583875a96d632566864f820c-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d381d443ffba143aed55856',
#        'name': 'Café Schweizer Konditori',
#        'location': {'address': 'Västerlånggatan 9',
#         'lat': 59.326174,
#         'lng': 18.068824,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.326174,
#           'lng': 18.068824}],
#         'distance': 174,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Västerlånggatan 9',
#          '111 29 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d381d443ffba143aed55856-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c63fd4479d1e21eacddd915',
#        'name': 'Café Stiernan',
#        'location': {'address': 'Österlånggatan 45',
#         'lat': 59.32340613732209,
#         'lng': 18.07359749940649,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32340613732209,
#           'lng': 18.07359749940649}],
#         'distance': 237,
#         'cc': 'SE',
#         'city': 'Storkyrkan',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Österlånggatan 45', 'Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '133752319'}},
#       'referralId': 'e-0-4c63fd4479d1e21eacddd915-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4baa44bcf964a52063593ae3',
#        'name': 'Gamla Stans Cykel',
#        'location': {'address': 'Stora Nygatan 44',
#         'crossStreet': 'Gamla Stan',
#         'lat': 59.323307552700676,
#         'lng': 18.070573427517328,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.323307552700676,
#           'lng': 18.070573427517328}],
#         'distance': 203,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora Nygatan 44 (Gamla Stan)',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d115951735',
#          'name': 'Bike Shop',
#          'pluralName': 'Bike Shops',
#          'shortName': 'Bike Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4baa44bcf964a52063593ae3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0a4f02a1b32d7f640b99f0',
#        'name': 'Gustaf III-statyn',
#        'location': {'address': 'Skeppsbron',
#         'lat': 59.32678018671347,
#         'lng': 18.07502950895078,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32678018671347,
#           'lng': 18.07502950895078}],
#         'distance': 290,
#         'postalCode': '111 30',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Skeppsbron', '111 30 Stockholm', 'Sverige']},
#        'categories': [{'id': '52e81612bcbc57f1066b79ed',
#          'name': 'Outdoor Sculpture',
#          'pluralName': 'Outdoor Sculptures',
#          'shortName': 'Outdoor Sculpture',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0a4f02a1b32d7f640b99f0-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdaecf964a520e75921e3',
#        'name': 'Chaikhana Tea House',
#        'location': {'address': 'Svartmangatan 21',
#         'lat': 59.32406789141911,
#         'lng': 18.072215051099608,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32406789141911,
#           'lng': 18.072215051099608}],
#         'distance': 133,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Svartmangatan 21',
#          '111 29 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcdaecf964a520e75921e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b180045f964a52039cb23e3',
#        'name': 'Österlånggatan 17',
#        'location': {'address': 'Österlånggatan 17',
#         'lat': 59.3251507,
#         'lng': 18.0740163,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.3251507,
#           'lng': 18.0740163}],
#         'distance': 166,
#         'postalCode': '111 31',
#         'cc': 'SE',
#         'neighborhood': 'Storkyrkan',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Österlånggatan 17',
#          '111 31 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1c6941735',
#          'name': 'Scandinavian Restaurant',
#          'pluralName': 'Scandinavian Restaurants',
#          'shortName': 'Scandinavian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b180045f964a52039cb23e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdaeef964a520ab5a21e3',
#        'name': 'Livrustkammaren | The Royal Armoury (Livrustkammaren)',
#        'location': {'address': 'Slottsbacken 3',
#         'lat': 59.32655302620751,
#         'lng': 18.073072971815968,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32655302620751,
#           'lng': 18.073072971815968}],
#         'distance': 195,
#         'postalCode': '111 30',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Slottsbacken 3', '111 30 Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcdaeef964a520ab5a21e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b292103f964a520539924e3',
#        'name': "O'Connells",
#        'location': {'address': 'Stora Nygatan 21',
#         'lat': 59.324423693525965,
#         'lng': 18.069038295541674,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.324423693525965,
#           'lng': 18.069038295541674}],
#         'distance': 139,
#         'postalCode': '111 27',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stora Nygatan 21',
#          '111 27 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a06',
#          'name': 'Irish Pub',
#          'pluralName': 'Irish Pubs',
#          'shortName': 'Irish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b292103f964a520539924e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdaedf964a520555a21e3',
#        'name': 'Kaffekoppen',
#        'location': {'address': 'Stortorget 20',
#         'lat': 59.32501605378984,
#         'lng': 18.070692897187275,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32501605378984,
#           'lng': 18.070692897187275}],
#         'distance': 25,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'neighborhood': 'Storkyrkan',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stortorget 20', '111 29 Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcdaedf964a520555a21e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4baba2c6f964a5206abb3ae3',
#        'name': 'Castanea Old Town Hostel',
#        'location': {'lat': 59.32475339350889,
#         'lng': 18.07275700599185,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32475339350889,
#           'lng': 18.07275700599185}],
#         'distance': 102,
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4baba2c6f964a5206abb3ae3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e198d6e18a8166f7396ffaa',
#        'name': 'Under Kastanjen',
#        'location': {'address': 'Brända tomten',
#         'crossStreet': 'btwn Kindstugatan & Själagårdsgatan',
#         'lat': 59.32479368667345,
#         'lng': 18.07289261214013,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32479368667345,
#           'lng': 18.07289261214013}],
#         'distance': 108,
#         'postalCode': '111 31',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Brända tomten (btwn Kindstugatan & Själagårdsgatan)',
#          '111 31 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e198d6e18a8166f7396ffaa-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '573c91a4498e4b5f105e5ba1',
#        'name': 'Skeppsbro Bageri',
#        'location': {'address': 'Skeppsbron 15',
#         'crossStreet': 'Tullhus 1',
#         'lat': 59.3248,
#         'lng': 18.076228,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.3248,
#           'lng': 18.076228}],
# ...
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd6cb8529eb9c74958c95e1',
#        'name': 'Mynttorget',
#        'location': {'address': 'Mynttorget',
#         'lat': 59.326869368500624,
#         'lng': 18.068546554388938,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.326869368500624,
#           'lng': 18.068546554388938}],
#         'distance': 242,
#         'postalCode': '111 28',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Mynttorget', '111 28 Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd6cb8529eb9c74958c95e1-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fe198aee4b01a0708ac8e2f',
#        'name': 'Inre borggården / Inner Courtyard (Inre borggården)',
#        'location': {'address': 'Kungliga Slottet',
#         'lat': 59.32636524314712,
#         'lng': 18.071840107179227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32636524314712,
#           'lng': 18.071840107179227}],
#         'distance': 145,
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Kungliga Slottet', 'Stockholm', 'Sverige']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fe198aee4b01a0708ac8e2f-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be8317b9a54a593eba40911',
#        'name': 'Mälardrottningen Yacht & Hotel',
#        'location': {'address': 'Södra Riddarholmshamnen',
#         'lat': 59.32409569534733,
#         'lng': 18.062579289005377,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32409569534733,
#           'lng': 18.062579289005377}],
#         'distance': 496,
#         'postalCode': '111 28',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Södra Riddarholmshamnen',
#          '111 28 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d12d951735',
#          'name': 'Boat or Ferry',
#          'pluralName': 'Boats or Ferries',
#          'shortName': 'Boat / Ferry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be8317b9a54a593eba40911-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50ca02c2245f2d4aa8c2bad0',
#        'name': 'Panorama Restaurant',
#        'location': {'address': 'Guldgränd 8',
#         'crossStreet': 'Hilton Stockholm Slussen',
#         'lat': 59.32075600496736,
#         'lng': 18.06906767157062,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32075600496736,
#           'lng': 18.06906767157062}],
#         'distance': 498,
#         'postalCode': '104 65',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Guldgränd 8 (Hilton Stockholm Slussen)',
#          '104 65 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50ca02c2245f2d4aa8c2bad0-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bea959c415e20a13024e5bb',
#        'name': 'Gustav Adolfs Torg',
#        'location': {'address': 'Gustav Adolfs Torg',
#         'lat': 59.32923188668454,
#         'lng': 18.068971947601167,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32923188668454,
#           'lng': 18.068971947601167}],
#         'distance': 473,
#         'postalCode': '111 52',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Gustav Adolfs Torg',
#          '111 52 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bea959c415e20a13024e5bb-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '553a646e498eb1b18ec63997',
#        'name': 'Brasseriet',
#        'location': {'address': 'Strömgatan 14',
#         'lat': 59.32931873337689,
#         'lng': 18.07029902989949,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32931873337689,
#           'lng': 18.07029902989949}],
#         'distance': 469,
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Strömgatan 14', 'Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-553a646e498eb1b18ec63997-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51c5bc58498e71cc05146af6',
#        'name': 'Under The Bridges Tour',
#        'location': {'address': 'Strömsätravägen',
#         'lat': 59.3293681908946,
#         'lng': 18.07385193243019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.3293681908946,
#           'lng': 18.07385193243019}],
#         'distance': 498,
#         'postalCode': '127 35',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Strömsätravägen',
#          '127 35 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d162941735',
#          'name': 'Other Great Outdoors',
#          'pluralName': 'Other Great Outdoors',
#          'shortName': 'Other Outdoors',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51c5bc58498e71cc05146af6-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c779735923ba1434b6e67e6',
#        'name': 'Myntkrogen',
#        'location': {'address': 'Slottsbacken 6',
#         'lat': 59.326109905208085,
#         'lng': 18.073019985743482,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.326109905208085,
#           'lng': 18.073019985743482}],
#         'distance': 155,
#         'postalCode': '111 30',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Slottsbacken 6', '111 30 Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1c6941735',
#          'name': 'Scandinavian Restaurant',
#          'pluralName': 'Scandinavian Restaurants',
#          'shortName': 'Scandinavian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c779735923ba1434b6e67e6-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec61dd9e3007199136fab1c',
#        'name': 'Museum Tre Kronor',
#        'location': {'lat': 59.32701888265357,
#         'lng': 18.07073494746731,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32701888265357,
#           'lng': 18.07073494746731}],
#         'distance': 212,
#         'cc': 'SE',
#         'neighborhood': 'Gamla st',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec61dd9e3007199136fab1c-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdaebf964a520bc5921e3',
#        'name': 'Zum Franziskaner',
#        'location': {'address': 'Skeppsbron 44',
#         'lat': 59.32239068885575,
#         'lng': 18.074312289722304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32239068885575,
#           'lng': 18.074312289722304}],
#         'distance': 354,
#         'postalCode': '111 30',
#         'cc': 'SE',
#         'neighborhood': 'Storkyrkan',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Skeppsbron 44', '111 30 Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d1c6941735',
#          'name': 'Scandinavian Restaurant',
#          'pluralName': 'Scandinavian Restaurants',
#          'shortName': 'Scandinavian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcdaebf964a520bc5921e3-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4afb376cf964a5202a1c22e3',
#        'name': 'Skeppsbar',
#        'location': {'address': 'Skeppsbron 44',
#         'lat': 59.32227379468638,
#         'lng': 18.074396985931045,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32227379468638,
#           'lng': 18.074396985931045}],
#         'distance': 367,
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Skeppsbron 44', 'Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4afb376cf964a5202a1c22e3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ad0514ce0c0c91d1b6da443',
#        'name': 'Gamla Stan, Stockholm',
#        'location': {'lat': 59.32506098638641,
#         'lng': 18.07071839813251,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.32506098638641,
#           'lng': 18.07071839813251}],
#         'distance': 22,
#         'postalCode': '111 29',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['111 29 Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ad0514ce0c0c91d1b6da443-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51bb0b1e498ed262ed5f91cd',
#        'name': 'Gamla riksdagshuset',
#        'location': {'address': 'Birger Jarls torg 5',
#         'lat': 59.324846,
#         'lng': 18.065033,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.324846,
#           'lng': 18.065033}],
#         'distance': 345,
#         'postalCode': '111 28',
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Birger Jarls torg 5',
#          '111 28 Stockholm',
#          'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d130941735',
#          'name': 'Building',
#          'pluralName': 'Buildings',
#          'shortName': 'Building',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51bb0b1e498ed262ed5f91cd-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59a2ecc94f0e5813f892f85c',
#        'name': 'Djurgården 11',
#        'location': {'lat': 59.322824,
#         'lng': 18.075922,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 59.322824,
#           'lng': 18.075922}],
#         'distance': 374,
#         'cc': 'SE',
#         'city': 'Stockholm',
#         'state': 'Storstockholm',
#         'country': 'Sverige',
#         'formattedAddress': ['Stockholm', 'Sverige']},
#        'categories': [{'id': '4bf58dd8d48988d12d951735',
#          'name': 'Boat or Ferry',
#          'pluralName': 'Boats or Ferries',
#          'shortName': 'Boat / Ferry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59a2ecc94f0e5813f892f85c-99'}]}]}}

# %% [markdown]
# #### Now we start pulling the data from Foursquare into a dataframe so we can manipulate and use it.

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#pull the actual data from the Foursquare API

venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues)
filtered_columns = ['venue.name', 'venue.id', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

nearby_venues
# Out:
#                                            venue.name  \
# 0                          Science Fiction Bokhandeln
# 1                                               Tweed
# 2                                          Stortorget
# 3                              Barrels Burgers & Beer
# 4                                 Stockholms Gästabud
# 5                                           Tradition
# 6                                         Corner Club
# 7                                        The Burgundy
# 8                                       Slingerbulten
# 9                                  The Hairy Pig Deli
# 10                               19 Glas Bar & Matsal
# 11                                      Wirströms Pub
# 12                                            Stampen
# 13                            Fabrique Stenugnsbageri
# 14                                         Pharmarium
# 15                                      Comics Heaven
# 16                Kungliga Slottet (Kungliga slottet)
# 17                                 Sound Pollution AB
# 18                                        Matgatan 22
# 19                                            Kryp In
# 20                                     Geronimo's FGT
# 21                            Gaston - Wine Exploring
# 22                                 AIFUR | krog & bar
# 23                                         Caffellini
# 24                                     Ardbeg Embassy
# 25                                     The Flying Elk
# 26                                   Royal Apartments
# 27                                             Kagges
# 28                           The Hairy Pig Restaurant
# 29                           Café Schweizer Konditori
# ..                                                ...
# 70                                  Riddarholmskyrkan
# 71  Skattkammaren | The Royal Treasury (Skattkamma...
# 72                                   The Bishops Arms
# 73                                     Magnus Ladulås
# 74                        Gamla Stans Polkagriskokeri
# 75                                      Operakällaren
# 76                                        Bröd & Salt
# 77  Medeltidsmuseet | Museum of Medieval Stockholm...
# 78                            Kungliga Myntkabinettet
# 79                            Cultur Bar & Restaurant
# 80                                    Kungliga Operan
# 81  Yttre borggård (Outer Courtyard) (Yttre borggå...
# 82                                     Strömparterren
# 83                                Sundbergs konditori
# 84                                     Strömterrassen
# 85                              Sara’s art and coffee
# 86                                         Mynttorget
# 87  Inre borggården / Inner Courtyard (Inre borggå...
# 88                     Mälardrottningen Yacht & Hotel
# 89                                Panorama Restaurant
# 90                                 Gustav Adolfs Torg
# 91                                         Brasseriet
# 92                             Under The Bridges Tour
# 93                                         Myntkrogen
# 94                                  Museum Tre Kronor
# 95                                   Zum Franziskaner
# 96                                          Skeppsbar
# 97                              Gamla Stan, Stockholm
# 98                                Gamla riksdagshuset
# 99                                      Djurgården 11
#
#                     venue.id         venue.categories  venue.location.lat  \
# 0   4b06fe89f964a520fef422e3                Bookstore           59.324047
# 1   51434b65e4b00cf8d47795f1             Cocktail Bar           59.324471
# 2   4b0e3607f964a520fa5523e3                    Plaza           59.324973
# 3   549447fb498ed7d33f190dc2             Burger Joint           59.324685
# 4   4e8596c602d59e1a9afa5d5e                Gastropub           59.325569
# 5   534d0a34498ef782062ac89c  Scandinavian Restaurant           59.325940
# 6   514c0868e4b07a3d6af2fca3             Cocktail Bar           59.323342
# 7   522784bb11d2164a04286219                 Wine Bar           59.324434
# 8   4ba0c261f964a520a77b37e3  Scandinavian Restaurant           59.324376
# 9   537f7e60498e54e075c24907            Deli / Bodega           59.325555
# 10  4b9a5e8ff964a52072af35e3                 Wine Bar           59.324633
# 11  4adcdaebf964a520ae5921e3                      Pub           59.324897
# 12  4adcdaedf964a5207c5a21e3                Jazz Club           59.325298
# 13  53a92582498eacb3853e0379                   Bakery           59.323625
# 14  51ccb742498e64f625f8ce57             Cocktail Bar           59.324851
# 15  4bcaf04afb84c9b624ee1d3e               Comic Shop           59.324369
# 16  4adcdaeef964a520c95a21e3                   Palace           59.326353
# 17  4c2dc7d5e307d13ad8510eda              Record Shop           59.324747
# 18  5729f110498e722233305953        Polish Restaurant           59.324454
# 19  4c78322f93ef236a9772ab0f  Scandinavian Restaurant           59.324694
# 20  550867d7498e86f0d8c9a61d       Mexican Restaurant           59.325198
# 21  50c0cc79e4b0a80fdc3460df                 Wine Bar           59.323206
# 22  4ece875cb634dd298f5ea304  Scandinavian Restaurant           59.323097
# 23  4dc28371887770a6be00accd                     Café           59.323560
# 24  4b63079df964a520945e2ae3  Scandinavian Restaurant           59.323170
# 25  50c0cbb9e4b01109e244886c                Gastropub           59.323085
# 26  53186d00498ec3e4b9002cd2            Historic Site           59.326226
# 27  58c90efcd243323eaf526efb  Scandinavian Restaurant           59.323371
# 28  583875a96d632566864f820c         Theme Restaurant           59.323738
# 29  4d381d443ffba143aed55856                     Café           59.326174
# ..                       ...                      ...                 ...
# 70  4ba642c3f964a5202e4039e3                   Church           59.325037
# 71  4efdd6ea0aaffcf6f27eb511           History Museum           59.326247
# 72  520fc34511d2e68fb213776a                      Pub           59.323006
# 73  4adcdaf0f964a5203f5b21e3  Scandinavian Restaurant           59.323841
# 74  51b9b404498e8ff70fc660fa              Candy Store           59.323769
# 75  4adcdaf1f964a520965b21e3  Scandinavian Restaurant           59.329506
# 76  596b81351acf1133ae142f01                   Bakery           59.323028
# 77  4b780cb4f964a52084b32ee3           History Museum           59.328301
# 78  4adcdaeff964a520015b21e3               Art Museum           59.326175
# 79  511a7c7ae4b0707c95d29680                 Wine Bar           59.323044
# 80  4adcdaf2f964a520ff5b21e3              Opera House           59.329498
# 81  4bdaa4723904a59331ee469e      Monument / Landmark           59.326280
# 82  4c194f766a21c9b6595eca97                     Park           59.328416
# 83  4bc576d4ccbcef3b3a93e6d2                     Café           59.322740
# 84  4e14315c483bfda2e0a3715c               Restaurant           59.329372
# 85  5a23bcd842d8c2528e087703           Breakfast Spot           59.324518
# 86  4bd6cb8529eb9c74958c95e1                    Plaza           59.326869
# 87  4fe198aee4b01a0708ac8e2f            Historic Site           59.326365
# 88  4be8317b9a54a593eba40911            Boat or Ferry           59.324096
# 89  50ca02c2245f2d4aa8c2bad0           Breakfast Spot           59.320756
# 90  4bea959c415e20a13024e5bb                    Plaza           59.329232
# 91  553a646e498eb1b18ec63997        French Restaurant           59.329319
# 92  51c5bc58498e71cc05146af6     Other Great Outdoors           59.329368
# 93  4c779735923ba1434b6e67e6  Scandinavian Restaurant           59.326110
# 94  4ec61dd9e3007199136fab1c           History Museum           59.327019
# 95  4adcdaebf964a520bc5921e3  Scandinavian Restaurant           59.322391
# 96  4afb376cf964a5202a1c22e3                      Bar           59.322274
# 97  5ad0514ce0c0c91d1b6da443                     Café           59.325061
# 98  51bb0b1e498ed262ed5f91cd                 Building           59.324846
# 99  59a2ecc94f0e5813f892f85c            Boat or Ferry           59.322824
#
#     venue.location.lng
# 0            18.070682
# 1            18.067696
# 2            18.070727
# 3            18.068513
# 4            18.073991
# 5            18.073710
# 6            18.069431
# 7            18.068161
# 8            18.068967
# 9            18.073958
# 10           18.068670
# 11           18.068192
# 12           18.067555
# 13           18.068700
# 14           18.070891
# 15           18.069033
# 16           18.071140
# 17           18.068459
# 18           18.068671
# 19           18.070059
# 20           18.067725
# 21           18.068640
# 22           18.071993
# 23           18.071373
# 24           18.071904
# 25           18.068833
# 26           18.071872
# 27           18.069441
# 28           18.068742
# 29           18.068824
# ..                 ...
# 70           18.065052
# 71           18.071876
# 72           18.068662
# 73           18.073726
# 74           18.068632
# 75           18.071626
# 76           18.075411
# 77           18.070309
# 78           18.073133
# 79           18.073469
# 80           18.069324
# 81           18.070276
# 82           18.070325
# 83           18.073046
# 84           18.070265
# 85           18.069800
# 86           18.068547
# 87           18.071840
# 88           18.062579
# 89           18.069068
# 90           18.068972
# 91           18.070299
# 92           18.073852
# 93           18.073020
# 94           18.070735
# 95           18.074312
# 96           18.074397
# 97           18.070718
# 98           18.065033
# 99           18.075922
#
# [100 rows x 5 columns]

# %%
#fix the column names so they look relatively normal
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
#                                                  name  \
# 0                          Science Fiction Bokhandeln
# 1                                               Tweed
# 2                                          Stortorget
# 3                              Barrels Burgers & Beer
# 4                                 Stockholms Gästabud
# 5                                           Tradition
# 6                                         Corner Club
# 7                                        The Burgundy
# 8                                       Slingerbulten
# 9                                  The Hairy Pig Deli
# 10                               19 Glas Bar & Matsal
# 11                                      Wirströms Pub
# 12                                            Stampen
# 13                            Fabrique Stenugnsbageri
# 14                                         Pharmarium
# 15                                      Comics Heaven
# 16                Kungliga Slottet (Kungliga slottet)
# 17                                 Sound Pollution AB
# 18                                        Matgatan 22
# 19                                            Kryp In
# 20                                     Geronimo's FGT
# 21                            Gaston - Wine Exploring
# 22                                 AIFUR | krog & bar
# 23                                         Caffellini
# 24                                     Ardbeg Embassy
# 25                                     The Flying Elk
# 26                                   Royal Apartments
# 27                                             Kagges
# 28                           The Hairy Pig Restaurant
# 29                           Café Schweizer Konditori
# ..                                                ...
# 70                                  Riddarholmskyrkan
# 71  Skattkammaren | The Royal Treasury (Skattkamma...
# 72                                   The Bishops Arms
# 73                                     Magnus Ladulås
# 74                        Gamla Stans Polkagriskokeri
# 75                                      Operakällaren
# 76                                        Bröd & Salt
# 77  Medeltidsmuseet | Museum of Medieval Stockholm...
# 78                            Kungliga Myntkabinettet
# 79                            Cultur Bar & Restaurant
# 80                                    Kungliga Operan
# 81  Yttre borggård (Outer Courtyard) (Yttre borggå...
# 82                                     Strömparterren
# 83                                Sundbergs konditori
# 84                                     Strömterrassen
# 85                              Sara’s art and coffee
# 86                                         Mynttorget
# 87  Inre borggården / Inner Courtyard (Inre borggå...
# 88                     Mälardrottningen Yacht & Hotel
# 89                                Panorama Restaurant
# 90                                 Gustav Adolfs Torg
# 91                                         Brasseriet
# 92                             Under The Bridges Tour
# 93                                         Myntkrogen
# 94                                  Museum Tre Kronor
# 95                                   Zum Franziskaner
# 96                                          Skeppsbar
# 97                              Gamla Stan, Stockholm
# 98                                Gamla riksdagshuset
# 99                                      Djurgården 11
#
#                           id               categories        lat        lng
# 0   4b06fe89f964a520fef422e3                Bookstore  59.324047  18.070682
# 1   51434b65e4b00cf8d47795f1             Cocktail Bar  59.324471  18.067696
# 2   4b0e3607f964a520fa5523e3                    Plaza  59.324973  18.070727
# 3   549447fb498ed7d33f190dc2             Burger Joint  59.324685  18.068513
# 4   4e8596c602d59e1a9afa5d5e                Gastropub  59.325569  18.073991
# 5   534d0a34498ef782062ac89c  Scandinavian Restaurant  59.325940  18.073710
# 6   514c0868e4b07a3d6af2fca3             Cocktail Bar  59.323342  18.069431
# 7   522784bb11d2164a04286219                 Wine Bar  59.324434  18.068161
# 8   4ba0c261f964a520a77b37e3  Scandinavian Restaurant  59.324376  18.068967
# 9   537f7e60498e54e075c24907            Deli / Bodega  59.325555  18.073958
# 10  4b9a5e8ff964a52072af35e3                 Wine Bar  59.324633  18.068670
# 11  4adcdaebf964a520ae5921e3                      Pub  59.324897  18.068192
# 12  4adcdaedf964a5207c5a21e3                Jazz Club  59.325298  18.067555
# 13  53a92582498eacb3853e0379                   Bakery  59.323625  18.068700
# 14  51ccb742498e64f625f8ce57             Cocktail Bar  59.324851  18.070891
# 15  4bcaf04afb84c9b624ee1d3e               Comic Shop  59.324369  18.069033
# 16  4adcdaeef964a520c95a21e3                   Palace  59.326353  18.071140
# 17  4c2dc7d5e307d13ad8510eda              Record Shop  59.324747  18.068459
# 18  5729f110498e722233305953        Polish Restaurant  59.324454  18.068671
# 19  4c78322f93ef236a9772ab0f  Scandinavian Restaurant  59.324694  18.070059
# 20  550867d7498e86f0d8c9a61d       Mexican Restaurant  59.325198  18.067725
# 21  50c0cc79e4b0a80fdc3460df                 Wine Bar  59.323206  18.068640
# 22  4ece875cb634dd298f5ea304  Scandinavian Restaurant  59.323097  18.071993
# 23  4dc28371887770a6be00accd                     Café  59.323560  18.071373
# 24  4b63079df964a520945e2ae3  Scandinavian Restaurant  59.323170  18.071904
# 25  50c0cbb9e4b01109e244886c                Gastropub  59.323085  18.068833
# 26  53186d00498ec3e4b9002cd2            Historic Site  59.326226  18.071872
# 27  58c90efcd243323eaf526efb  Scandinavian Restaurant  59.323371  18.069441
# 28  583875a96d632566864f820c         Theme Restaurant  59.323738  18.068742
# 29  4d381d443ffba143aed55856                     Café  59.326174  18.068824
# ..                       ...                      ...        ...        ...
# 70  4ba642c3f964a5202e4039e3                   Church  59.325037  18.065052
# 71  4efdd6ea0aaffcf6f27eb511           History Museum  59.326247  18.071876
# 72  520fc34511d2e68fb213776a                      Pub  59.323006  18.068662
# 73  4adcdaf0f964a5203f5b21e3  Scandinavian Restaurant  59.323841  18.073726
# 74  51b9b404498e8ff70fc660fa              Candy Store  59.323769  18.068632
# 75  4adcdaf1f964a520965b21e3  Scandinavian Restaurant  59.329506  18.071626
# 76  596b81351acf1133ae142f01                   Bakery  59.323028  18.075411
# 77  4b780cb4f964a52084b32ee3           History Museum  59.328301  18.070309
# 78  4adcdaeff964a520015b21e3               Art Museum  59.326175  18.073133
# 79  511a7c7ae4b0707c95d29680                 Wine Bar  59.323044  18.073469
# 80  4adcdaf2f964a520ff5b21e3              Opera House  59.329498  18.069324
# 81  4bdaa4723904a59331ee469e      Monument / Landmark  59.326280  18.070276
# 82  4c194f766a21c9b6595eca97                     Park  59.328416  18.070325
# 83  4bc576d4ccbcef3b3a93e6d2                     Café  59.322740  18.073046
# 84  4e14315c483bfda2e0a3715c               Restaurant  59.329372  18.070265
# 85  5a23bcd842d8c2528e087703           Breakfast Spot  59.324518  18.069800
# 86  4bd6cb8529eb9c74958c95e1                    Plaza  59.326869  18.068547
# 87  4fe198aee4b01a0708ac8e2f            Historic Site  59.326365  18.071840
# 88  4be8317b9a54a593eba40911            Boat or Ferry  59.324096  18.062579
# 89  50ca02c2245f2d4aa8c2bad0           Breakfast Spot  59.320756  18.069068
# 90  4bea959c415e20a13024e5bb                    Plaza  59.329232  18.068972
# 91  553a646e498eb1b18ec63997        French Restaurant  59.329319  18.070299
# 92  51c5bc58498e71cc05146af6     Other Great Outdoors  59.329368  18.073852
# 93  4c779735923ba1434b6e67e6  Scandinavian Restaurant  59.326110  18.073020
# 94  4ec61dd9e3007199136fab1c           History Museum  59.327019  18.070735
# 95  4adcdaebf964a520bc5921e3  Scandinavian Restaurant  59.322391  18.074312
# 96  4afb376cf964a5202a1c22e3                      Bar  59.322274  18.074397
# 97  5ad0514ce0c0c91d1b6da443                     Café  59.325061  18.070718
# 98  51bb0b1e498ed262ed5f91cd                 Building  59.324846  18.065033
# 99  59a2ecc94f0e5813f892f85c            Boat or Ferry  59.322824  18.075922
#
# [100 rows x 5 columns]

# %% [markdown]
# Looking good. Let's now place all this into a Pandas dataframe.

# %%
nearby_venues['categories'].unique()
# Out:
# array(['Bookstore', 'Cocktail Bar', 'Plaza', 'Burger Joint', 'Gastropub',
#        'Scandinavian Restaurant', 'Wine Bar', 'Deli / Bodega', 'Pub',
#        'Jazz Club', 'Bakery', 'Comic Shop', 'Palace', 'Record Shop',
#        'Polish Restaurant', 'Mexican Restaurant', 'Café', 'Historic Site',
#        'Theme Restaurant', 'Noodle House', 'Bike Shop',
#        'Outdoor Sculpture', 'Tea Room', 'History Museum', 'Irish Pub',
#        'Hostel', 'Ice Cream Shop', 'Italian Restaurant', 'Coffee Shop',
#        'Gift Shop', 'French Restaurant', 'BBQ Joint', 'German Restaurant',
#        'Toy / Game Store', 'Bar', 'Restaurant', 'Fish & Chips Shop',
#        'Seafood Restaurant', 'Hotel', 'Museum', 'Sushi Restaurant',
#        'Church', 'Candy Store', 'Art Museum', 'Opera House',
#        'Monument / Landmark', 'Park', 'Breakfast Spot', 'Boat or Ferry',
#        'Other Great Outdoors', 'Building'], dtype=object)

# %% [markdown]
# ...and let's now save/persist this data into local file.

# %%
# creating a list of categorie to remove from our dataframe because they are not restaurants
# I am sure there is a function that can be written to do this at scale but since it was a small list, I did it manually

removal_list = ['Bookstore', 'Bakery', 'Jazz Club', "Bike Shop", 'Comic Shop', 'Plaza', 'Gastropub',
               'Record Shop', 'Pub', 'Pet Store', 'Historic Site', 'Outdoor Sculpture', 'Tea Room', 'History Museum', 'Irish Pub',
       'Hostel','Gift Shop','BBQ Joint','Toy / Game Store', 'Bar','Fish & Chips Shop','Hotel', 'Museum','Church', 'Candy Store', 'Art Museum', 'Opera House',
       'Monument / Landmark', 'Park', 'Breakfast Spot', 'Boat or Ferry',
       'Other Great Outdoors', 'Building']

nearby_venues2 = nearby_venues.copy()


#getting a clear dataframe of just restaurants
nearby_venues2 = nearby_venues2[~nearby_venues2['categories'].isin(removal_list)]
nearby_venues2
# Out:
#                                    name                        id  \
# 1                                 Tweed  51434b65e4b00cf8d47795f1
# 3                Barrels Burgers & Beer  549447fb498ed7d33f190dc2
# 5                             Tradition  534d0a34498ef782062ac89c
# 6                           Corner Club  514c0868e4b07a3d6af2fca3
# 7                          The Burgundy  522784bb11d2164a04286219
# 8                         Slingerbulten  4ba0c261f964a520a77b37e3
# 9                    The Hairy Pig Deli  537f7e60498e54e075c24907
# 10                 19 Glas Bar & Matsal  4b9a5e8ff964a52072af35e3
# 14                           Pharmarium  51ccb742498e64f625f8ce57
# 16  Kungliga Slottet (Kungliga slottet)  4adcdaeef964a520c95a21e3
# 18                          Matgatan 22  5729f110498e722233305953
# 19                              Kryp In  4c78322f93ef236a9772ab0f
# 20                       Geronimo's FGT  550867d7498e86f0d8c9a61d
# 21              Gaston - Wine Exploring  50c0cc79e4b0a80fdc3460df
# 22                   AIFUR | krog & bar  4ece875cb634dd298f5ea304
# 23                           Caffellini  4dc28371887770a6be00accd
# 24                       Ardbeg Embassy  4b63079df964a520945e2ae3
# 27                               Kagges  58c90efcd243323eaf526efb
# 28             The Hairy Pig Restaurant  583875a96d632566864f820c
# 29             Café Schweizer Konditori  4d381d443ffba143aed55856
# 30                        Café Stiernan  4c63fd4479d1e21eacddd915
# 34                    Österlånggatan 17  4b180045f964a52039cb23e3
# 37                          Kaffekoppen  4adcdaedf964a520555a21e3
# 39                      Under Kastanjen  4e198d6e18a8166f7396ffaa
# 41                   Den Gyldene Freden  4adcdaf0f964a520655b21e3
# 42                        Chokladkoppen  4adcdaebf964a520e35921e3
# 43                          StikkiNikki  5731e745498ea03b4bfe08cb
# 45                      Corvina Enoteca  51cb1bd3498e9a51850326c1
# 46                           CitySallad  4d66061b48ee6ea85d166168
# 48                               Pastis  4b583319f964a520bf4d28e3
# 53                  S:ta Clara Bierhaus  4c9cb5199975a143948034cf
# 55                  Ristorante da Peppe  4b9a284ef964a520d7a135e3
# 60                   Restaurang Brinken  55df60fd498e44d120c585cb
# 62                           Mr. French  51829a91498e80962fe0411e
# 63                             Cafe Dox  4b4f5698f964a520f60127e3
# 65                            Rodolfino  4c62750486b6be9ae3138c34
# 66                          Fem små hus  4b880a56f964a52018db31e3
# 69                          Mogge Sushi  58ce88c415fb435821a3bd22
# 73                       Magnus Ladulås  4adcdaf0f964a5203f5b21e3
# 75                        Operakällaren  4adcdaf1f964a520965b21e3
# 79              Cultur Bar & Restaurant  511a7c7ae4b0707c95d29680
# 83                  Sundbergs konditori  4bc576d4ccbcef3b3a93e6d2
# 84                       Strömterrassen  4e14315c483bfda2e0a3715c
# 91                           Brasseriet  553a646e498eb1b18ec63997
# 93                           Myntkrogen  4c779735923ba1434b6e67e6
# 95                     Zum Franziskaner  4adcdaebf964a520bc5921e3
# 97                Gamla Stan, Stockholm  5ad0514ce0c0c91d1b6da443
#
#                  categories        lat        lng
# 1              Cocktail Bar  59.324471  18.067696
# 3              Burger Joint  59.324685  18.068513
# 5   Scandinavian Restaurant  59.325940  18.073710
# 6              Cocktail Bar  59.323342  18.069431
# 7                  Wine Bar  59.324434  18.068161
# 8   Scandinavian Restaurant  59.324376  18.068967
# 9             Deli / Bodega  59.325555  18.073958
# 10                 Wine Bar  59.324633  18.068670
# 14             Cocktail Bar  59.324851  18.070891
# 16                   Palace  59.326353  18.071140
# 18        Polish Restaurant  59.324454  18.068671
# 19  Scandinavian Restaurant  59.324694  18.070059
# 20       Mexican Restaurant  59.325198  18.067725
# 21                 Wine Bar  59.323206  18.068640
# 22  Scandinavian Restaurant  59.323097  18.071993
# 23                     Café  59.323560  18.071373
# 24  Scandinavian Restaurant  59.323170  18.071904
# 27  Scandinavian Restaurant  59.323371  18.069441
# 28         Theme Restaurant  59.323738  18.068742
# 29                     Café  59.326174  18.068824
# 30             Noodle House  59.323406  18.073597
# 34  Scandinavian Restaurant  59.325151  18.074016
# 37                     Café  59.325016  18.070693
# 39                     Café  59.324794  18.072893
# 41  Scandinavian Restaurant  59.323159  18.073512
# 42                     Café  59.325020  18.070727
# 43           Ice Cream Shop  59.324699  18.068485
# 45       Italian Restaurant  59.323060  18.071104
# 46              Coffee Shop  59.326088  18.075268
# 48        French Restaurant  59.325093  18.073573
# 53        German Restaurant  59.323579  18.069006
# 55       Italian Restaurant  59.325878  18.067292
# 60               Restaurant  59.324204  18.068696
# 62       Seafood Restaurant  59.323966  18.075842
# 63                     Café  59.323921  18.069635
# 65       Italian Restaurant  59.325854  18.066945
# 66  Scandinavian Restaurant  59.325200  18.073931
# 69         Sushi Restaurant  59.324777  18.066829
# 73  Scandinavian Restaurant  59.323841  18.073726
# 75  Scandinavian Restaurant  59.329506  18.071626
# 79                 Wine Bar  59.323044  18.073469
# 83                     Café  59.322740  18.073046
# 84               Restaurant  59.329372  18.070265
# 91        French Restaurant  59.329319  18.070299
# 93  Scandinavian Restaurant  59.326110  18.073020
# 95  Scandinavian Restaurant  59.322391  18.074312
# 97                     Café  59.325061  18.070718

# %% [markdown]
# #### Now let's get a list of venue ids so we can pull likes and add to our dataframe.

# %%
#let's get a list of venues

venue_id_list = nearby_venues2['id'].tolist()
venue_id_list
# Out:
# ['51434b65e4b00cf8d47795f1',
#  '549447fb498ed7d33f190dc2',
#  '534d0a34498ef782062ac89c',
#  '514c0868e4b07a3d6af2fca3',
#  '522784bb11d2164a04286219',
#  '4ba0c261f964a520a77b37e3',
#  '537f7e60498e54e075c24907',
#  '4b9a5e8ff964a52072af35e3',
#  '51ccb742498e64f625f8ce57',
#  '4adcdaeef964a520c95a21e3',
#  '5729f110498e722233305953',
#  '4c78322f93ef236a9772ab0f',
#  '550867d7498e86f0d8c9a61d',
#  '50c0cc79e4b0a80fdc3460df',
#  '4ece875cb634dd298f5ea304',
#  '4dc28371887770a6be00accd',
#  '4b63079df964a520945e2ae3',
#  '58c90efcd243323eaf526efb',
#  '583875a96d632566864f820c',
#  '4d381d443ffba143aed55856',
#  '4c63fd4479d1e21eacddd915',
#  '4b180045f964a52039cb23e3',
#  '4adcdaedf964a520555a21e3',
#  '4e198d6e18a8166f7396ffaa',
#  '4adcdaf0f964a520655b21e3',
#  '4adcdaebf964a520e35921e3',
#  '5731e745498ea03b4bfe08cb',
#  '51cb1bd3498e9a51850326c1',
#  '4d66061b48ee6ea85d166168',
#  '4b583319f964a520bf4d28e3',
#  '4c9cb5199975a143948034cf',
#  '4b9a284ef964a520d7a135e3',
#  '55df60fd498e44d120c585cb',
#  '51829a91498e80962fe0411e',
#  '4b4f5698f964a520f60127e3',
#  '4c62750486b6be9ae3138c34',
#  '4b880a56f964a52018db31e3',
#  '58ce88c415fb435821a3bd22',
#  '4adcdaf0f964a5203f5b21e3',
#  '4adcdaf1f964a520965b21e3',
#  '511a7c7ae4b0707c95d29680',
#  '4bc576d4ccbcef3b3a93e6d2',
#  '4e14315c483bfda2e0a3715c',
#  '553a646e498eb1b18ec63997',
#  '4c779735923ba1434b6e67e6',
#  '4adcdaebf964a520bc5921e3',
#  '5ad0514ce0c0c91d1b6da443']

# %%
#set up to pull the likes from the API based on venue ID

url_list = []
like_list = []
json_list = []

for i in venue_id_list:
    venue_url = 'https://api.foursquare.com/v2/venues/{}/likes?client_id={}&client_secret={}&v={}'.format(i, CLIENT_ID, CLIENT_SECRET, VERSION)
    url_list.append(venue_url)
for link in url_list:
    result = requests.get(link).json()
    likes = result['response']['likes']['count']
    like_list.append(likes)
print(like_list)
# Out:
# [198, 448, 96, 101, 40, 128, 100, 109, 178, 497, 27, 120, 75, 69, 271, 33, 144, 14, 24, 104, 75, 112, 99, 217, 114, 221, 23, 30, 14, 35, 34, 45, 8, 152, 36, 53, 60, 14, 19, 64, 57, 60, 20, 24, 6, 31, 8]

# %%
#double check that we did not lose any venues based on if likes were available

print(len(like_list))
print(len(venue_id_list))
# Out:
# 47
# 47

# %% [markdown]
# ### Data Prep Intro
# We thought likes are a proxy for quality. The more likes there are, the better the restaurant is. This might be incorrect but API call issues (how many I can use for free) holds me back from getting price / rating data. I will then bin this data into a quality categorical variables so we can cluster appropriately.
#
# I am also going to create new categorical variables for the restaurants to better group them based on type of cuisine. This way you can look for good mexican food or now what type of food might be best to eat in Hoboken if you are new to the area.
#
# ### Data Prep Part 1
# Now let's start prepping our data for clustering. This will include combining data from different lists, creating new categorical data to be used, binning data and then encoding the data for clustering.

# %%
#let's make a copy of our initial dataframe just in case anything goes wrong

stockholm_venues = nearby_venues2.copy()
stockholm_venues.head()
# Out:
#                      name                        id               categories  \
# 1                   Tweed  51434b65e4b00cf8d47795f1             Cocktail Bar
# 3  Barrels Burgers & Beer  549447fb498ed7d33f190dc2             Burger Joint
# 5               Tradition  534d0a34498ef782062ac89c  Scandinavian Restaurant
# 6             Corner Club  514c0868e4b07a3d6af2fca3             Cocktail Bar
# 7            The Burgundy  522784bb11d2164a04286219                 Wine Bar
#
#          lat        lng
# 1  59.324471  18.067696
# 3  59.324685  18.068513
# 5  59.325940  18.073710
# 6  59.323342  18.069431
# 7  59.324434  18.068161

# %% [markdown]
# ### Data Prep Part 2

# %%
# add in the list of likes

stockholm_venues['total likes'] = like_list
stockholm_venues.head()
# Out:
#                      name                        id               categories  \
# 1                   Tweed  51434b65e4b00cf8d47795f1             Cocktail Bar
# 3  Barrels Burgers & Beer  549447fb498ed7d33f190dc2             Burger Joint
# 5               Tradition  534d0a34498ef782062ac89c  Scandinavian Restaurant
# 6             Corner Club  514c0868e4b07a3d6af2fca3             Cocktail Bar
# 7            The Burgundy  522784bb11d2164a04286219                 Wine Bar
#
#          lat        lng  total likes
# 1  59.324471  18.067696          198
# 3  59.324685  18.068513          448
# 5  59.325940  18.073710           96
# 6  59.323342  18.069431          101
# 7  59.324434  18.068161           40

# %% [markdown]
# ### Data Prep Part 3

# %%
# now let's bin total likes

print(stockholm_venues['total likes'].max())
print(stockholm_venues['total likes'].min())
print(stockholm_venues['total likes'].median())
print(stockholm_venues['total likes'].mean())
# Out:
# 497
# 6
# 60.0
# 93.76595744680851

# %%
import matplotlib.pyplot as plt
stockholm_venues['total likes'].hist(bins=4)
plt.show()

# %%
# what are the bins we want to use?
print(np.percentile(stockholm_venues['total likes'], 25))
print(np.percentile(stockholm_venues['total likes'], 50))
print(np.percentile(stockholm_venues['total likes'], 75))
# Out:
# 28.5
# 60.0
# 113.0

# %%
# now we have our bin values so let's set them to the appropriate values
# less than 24, 24-45, 45-76, 76>
# poor, below avg, abv avg, great

poor = stockholm_venues['total likes']<=24
below_avg = stockholm_venues[(stockholm_venues['total likes']>24) & (stockholm_venues['total likes']<=45)]
abv_avg = stockholm_venues[(stockholm_venues['total likes']>45) & (stockholm_venues['total likes']<=76)]
great = stockholm_venues['total likes']>76

# %%
stockholm_venues
# Out:
#                                    name                        id  \
# 1                                 Tweed  51434b65e4b00cf8d47795f1
# 3                Barrels Burgers & Beer  549447fb498ed7d33f190dc2
# 5                             Tradition  534d0a34498ef782062ac89c
# 6                           Corner Club  514c0868e4b07a3d6af2fca3
# 7                          The Burgundy  522784bb11d2164a04286219
# 8                         Slingerbulten  4ba0c261f964a520a77b37e3
# 9                    The Hairy Pig Deli  537f7e60498e54e075c24907
# 10                 19 Glas Bar & Matsal  4b9a5e8ff964a52072af35e3
# 14                           Pharmarium  51ccb742498e64f625f8ce57
# 16  Kungliga Slottet (Kungliga slottet)  4adcdaeef964a520c95a21e3
# 18                          Matgatan 22  5729f110498e722233305953
# 19                              Kryp In  4c78322f93ef236a9772ab0f
# 20                       Geronimo's FGT  550867d7498e86f0d8c9a61d
# 21              Gaston - Wine Exploring  50c0cc79e4b0a80fdc3460df
# 22                   AIFUR | krog & bar  4ece875cb634dd298f5ea304
# 23                           Caffellini  4dc28371887770a6be00accd
# 24                       Ardbeg Embassy  4b63079df964a520945e2ae3
# 27                               Kagges  58c90efcd243323eaf526efb
# 28             The Hairy Pig Restaurant  583875a96d632566864f820c
# 29             Café Schweizer Konditori  4d381d443ffba143aed55856
# 30                        Café Stiernan  4c63fd4479d1e21eacddd915
# 34                    Österlånggatan 17  4b180045f964a52039cb23e3
# 37                          Kaffekoppen  4adcdaedf964a520555a21e3
# 39                      Under Kastanjen  4e198d6e18a8166f7396ffaa
# 41                   Den Gyldene Freden  4adcdaf0f964a520655b21e3
# 42                        Chokladkoppen  4adcdaebf964a520e35921e3
# 43                          StikkiNikki  5731e745498ea03b4bfe08cb
# 45                      Corvina Enoteca  51cb1bd3498e9a51850326c1
# 46                           CitySallad  4d66061b48ee6ea85d166168
# 48                               Pastis  4b583319f964a520bf4d28e3
# 53                  S:ta Clara Bierhaus  4c9cb5199975a143948034cf
# 55                  Ristorante da Peppe  4b9a284ef964a520d7a135e3
# 60                   Restaurang Brinken  55df60fd498e44d120c585cb
# 62                           Mr. French  51829a91498e80962fe0411e
# 63                             Cafe Dox  4b4f5698f964a520f60127e3
# 65                            Rodolfino  4c62750486b6be9ae3138c34
# 66                          Fem små hus  4b880a56f964a52018db31e3
# 69                          Mogge Sushi  58ce88c415fb435821a3bd22
# 73                       Magnus Ladulås  4adcdaf0f964a5203f5b21e3
# 75                        Operakällaren  4adcdaf1f964a520965b21e3
# 79              Cultur Bar & Restaurant  511a7c7ae4b0707c95d29680
# 83                  Sundbergs konditori  4bc576d4ccbcef3b3a93e6d2
# 84                       Strömterrassen  4e14315c483bfda2e0a3715c
# 91                           Brasseriet  553a646e498eb1b18ec63997
# 93                           Myntkrogen  4c779735923ba1434b6e67e6
# 95                     Zum Franziskaner  4adcdaebf964a520bc5921e3
# 97                Gamla Stan, Stockholm  5ad0514ce0c0c91d1b6da443
#
#                  categories        lat        lng  total likes
# 1              Cocktail Bar  59.324471  18.067696          198
# 3              Burger Joint  59.324685  18.068513          448
# 5   Scandinavian Restaurant  59.325940  18.073710           96
# 6              Cocktail Bar  59.323342  18.069431          101
# 7                  Wine Bar  59.324434  18.068161           40
# 8   Scandinavian Restaurant  59.324376  18.068967          128
# 9             Deli / Bodega  59.325555  18.073958          100
# 10                 Wine Bar  59.324633  18.068670          109
# 14             Cocktail Bar  59.324851  18.070891          178
# 16                   Palace  59.326353  18.071140          497
# 18        Polish Restaurant  59.324454  18.068671           27
# 19  Scandinavian Restaurant  59.324694  18.070059          120
# 20       Mexican Restaurant  59.325198  18.067725           75
# 21                 Wine Bar  59.323206  18.068640           69
# 22  Scandinavian Restaurant  59.323097  18.071993          271
# 23                     Café  59.323560  18.071373           33
# 24  Scandinavian Restaurant  59.323170  18.071904          144
# 27  Scandinavian Restaurant  59.323371  18.069441           14
# 28         Theme Restaurant  59.323738  18.068742           24
# 29                     Café  59.326174  18.068824          104
# 30             Noodle House  59.323406  18.073597           75
# 34  Scandinavian Restaurant  59.325151  18.074016          112
# 37                     Café  59.325016  18.070693           99
# 39                     Café  59.324794  18.072893          217
# 41  Scandinavian Restaurant  59.323159  18.073512          114
# 42                     Café  59.325020  18.070727          221
# 43           Ice Cream Shop  59.324699  18.068485           23
# 45       Italian Restaurant  59.323060  18.071104           30
# 46              Coffee Shop  59.326088  18.075268           14
# 48        French Restaurant  59.325093  18.073573           35
# 53        German Restaurant  59.323579  18.069006           34
# 55       Italian Restaurant  59.325878  18.067292           45
# 60               Restaurant  59.324204  18.068696            8
# 62       Seafood Restaurant  59.323966  18.075842          152
# 63                     Café  59.323921  18.069635           36
# 65       Italian Restaurant  59.325854  18.066945           53
# 66  Scandinavian Restaurant  59.325200  18.073931           60
# 69         Sushi Restaurant  59.324777  18.066829           14
# 73  Scandinavian Restaurant  59.323841  18.073726           19
# 75  Scandinavian Restaurant  59.329506  18.071626           64
# 79                 Wine Bar  59.323044  18.073469           57
# 83                     Café  59.322740  18.073046           60
# 84               Restaurant  59.329372  18.070265           20
# 91        French Restaurant  59.329319  18.070299           24
# 93  Scandinavian Restaurant  59.326110  18.073020            6
# 95  Scandinavian Restaurant  59.322391  18.074312           31
# 97                     Café  59.325061  18.070718            8

# %%
# let's star the process for re-categorizing the categories

stockholm_venues['categories'].unique()
# Out:
# array(['Cocktail Bar', 'Burger Joint', 'Scandinavian Restaurant',
#        'Wine Bar', 'Deli / Bodega', 'Palace', 'Polish Restaurant',
#        'Mexican Restaurant', 'Café', 'Theme Restaurant', 'Noodle House',
#        'Ice Cream Shop', 'Italian Restaurant', 'Coffee Shop',
#        'French Restaurant', 'German Restaurant', 'Restaurant',
#        'Seafood Restaurant', 'Sushi Restaurant'], dtype=object)

# %%
# let's create our new categories and create a function to apply those to our existing data

bars = ['Pub', 'Cocktail Bar', 'Bar', 'Dive Bar', 'Sports Bar']
other = ['Bagel Shop', 'Tea Room', 'Donut Shop', 'Coffee Shop', 'Bubble Tea Shop', 'Sandwich Place', 'Boutique', 'Ice Cream Shop']
euro_asia_indian_food = ['Falafel Restaurant', 'Korean Restaurant','Sushi Restaurant', 'Indian Restaurant', 'Japanese Restaurant', 'Poke Place', 'Thai Restaurant', 'Vietnamese Restaurant']
mex_southam_food = ['Cuban Restaurant', 'Mexican Restaurant', 'South American Restaurant', 'Latin American Restaurant']
american_food = ['Burger Joint', 'Restaurant', 'American Restaurant']
italian_food = ['Italian Restaurant', 'Seafood Restaurant', 'Pizza Place']

def conditions2(s):
    if s['categories'] in bars:
        return 'bars'
    if s['categories'] in other:
        return 'other'
    if s['categories'] in euro_asia_indian_food:
        return 'euro asia indian food'
    if s['categories'] in mex_southam_food:
        return 'mex southam food'
    if s['categories'] in american_food:
        return 'american food'
    if s['categories'] in italian_food:
        return 'italian food'

hoboken_venues['categories_new']=hoboken_venues.apply(conditions2, axis=1)

# %%
stockholm_venues
# Out:
#                                    name                        id  \
# 1                                 Tweed  51434b65e4b00cf8d47795f1
# 3                Barrels Burgers & Beer  549447fb498ed7d33f190dc2
# 5                             Tradition  534d0a34498ef782062ac89c
# 6                           Corner Club  514c0868e4b07a3d6af2fca3
# 7                          The Burgundy  522784bb11d2164a04286219
# 8                         Slingerbulten  4ba0c261f964a520a77b37e3
# 9                    The Hairy Pig Deli  537f7e60498e54e075c24907
# 10                 19 Glas Bar & Matsal  4b9a5e8ff964a52072af35e3
# 14                           Pharmarium  51ccb742498e64f625f8ce57
# 16  Kungliga Slottet (Kungliga slottet)  4adcdaeef964a520c95a21e3
# 18                          Matgatan 22  5729f110498e722233305953
# 19                              Kryp In  4c78322f93ef236a9772ab0f
# 20                       Geronimo's FGT  550867d7498e86f0d8c9a61d
# 21              Gaston - Wine Exploring  50c0cc79e4b0a80fdc3460df
# 22                   AIFUR | krog & bar  4ece875cb634dd298f5ea304
# 23                           Caffellini  4dc28371887770a6be00accd
# 24                       Ardbeg Embassy  4b63079df964a520945e2ae3
# 27                               Kagges  58c90efcd243323eaf526efb
# 28             The Hairy Pig Restaurant  583875a96d632566864f820c
# 29             Café Schweizer Konditori  4d381d443ffba143aed55856
# 30                        Café Stiernan  4c63fd4479d1e21eacddd915
# 34                    Österlånggatan 17  4b180045f964a52039cb23e3
# 37                          Kaffekoppen  4adcdaedf964a520555a21e3
# 39                      Under Kastanjen  4e198d6e18a8166f7396ffaa
# 41                   Den Gyldene Freden  4adcdaf0f964a520655b21e3
# 42                        Chokladkoppen  4adcdaebf964a520e35921e3
# 43                          StikkiNikki  5731e745498ea03b4bfe08cb
# 45                      Corvina Enoteca  51cb1bd3498e9a51850326c1
# 46                           CitySallad  4d66061b48ee6ea85d166168
# 48                               Pastis  4b583319f964a520bf4d28e3
# 53                  S:ta Clara Bierhaus  4c9cb5199975a143948034cf
# 55                  Ristorante da Peppe  4b9a284ef964a520d7a135e3
# 60                   Restaurang Brinken  55df60fd498e44d120c585cb
# 62                           Mr. French  51829a91498e80962fe0411e
# 63                             Cafe Dox  4b4f5698f964a520f60127e3
# 65                            Rodolfino  4c62750486b6be9ae3138c34
# 66                          Fem små hus  4b880a56f964a52018db31e3
# 69                          Mogge Sushi  58ce88c415fb435821a3bd22
# 73                       Magnus Ladulås  4adcdaf0f964a5203f5b21e3
# 75                        Operakällaren  4adcdaf1f964a520965b21e3
# 79              Cultur Bar & Restaurant  511a7c7ae4b0707c95d29680
# 83                  Sundbergs konditori  4bc576d4ccbcef3b3a93e6d2
# 84                       Strömterrassen  4e14315c483bfda2e0a3715c
# 91                           Brasseriet  553a646e498eb1b18ec63997
# 93                           Myntkrogen  4c779735923ba1434b6e67e6
# 95                     Zum Franziskaner  4adcdaebf964a520bc5921e3
# 97                Gamla Stan, Stockholm  5ad0514ce0c0c91d1b6da443
#
#                  categories        lat        lng  total likes  \
# 1              Cocktail Bar  59.324471  18.067696          198
# 3              Burger Joint  59.324685  18.068513          448
# 5   Scandinavian Restaurant  59.325940  18.073710           96
# 6              Cocktail Bar  59.323342  18.069431          101
# 7                  Wine Bar  59.324434  18.068161           40
# 8   Scandinavian Restaurant  59.324376  18.068967          128
# 9             Deli / Bodega  59.325555  18.073958          100
# 10                 Wine Bar  59.324633  18.068670          109
# 14             Cocktail Bar  59.324851  18.070891          178
# 16                   Palace  59.326353  18.071140          497
# 18        Polish Restaurant  59.324454  18.068671           27
# 19  Scandinavian Restaurant  59.324694  18.070059          120
# 20       Mexican Restaurant  59.325198  18.067725           75
# 21                 Wine Bar  59.323206  18.068640           69
# 22  Scandinavian Restaurant  59.323097  18.071993          271
# 23                     Café  59.323560  18.071373           33
# 24  Scandinavian Restaurant  59.323170  18.071904          144
# 27  Scandinavian Restaurant  59.323371  18.069441           14
# 28         Theme Restaurant  59.323738  18.068742           24
# 29                     Café  59.326174  18.068824          104
# 30             Noodle House  59.323406  18.073597           75
# 34  Scandinavian Restaurant  59.325151  18.074016          112
# 37                     Café  59.325016  18.070693           99
# 39                     Café  59.324794  18.072893          217
# 41  Scandinavian Restaurant  59.323159  18.073512          114
# 42                     Café  59.325020  18.070727          221
# 43           Ice Cream Shop  59.324699  18.068485           23
# 45       Italian Restaurant  59.323060  18.071104           30
# 46              Coffee Shop  59.326088  18.075268           14
# 48        French Restaurant  59.325093  18.073573           35
# 53        German Restaurant  59.323579  18.069006           34
# 55       Italian Restaurant  59.325878  18.067292           45
# 60               Restaurant  59.324204  18.068696            8
# 62       Seafood Restaurant  59.323966  18.075842          152
# 63                     Café  59.323921  18.069635           36
# 65       Italian Restaurant  59.325854  18.066945           53
# 66  Scandinavian Restaurant  59.325200  18.073931           60
# 69         Sushi Restaurant  59.324777  18.066829           14
# 73  Scandinavian Restaurant  59.323841  18.073726           19
# 75  Scandinavian Restaurant  59.329506  18.071626           64
# 79                 Wine Bar  59.323044  18.073469           57
# 83                     Café  59.322740  18.073046           60
# 84               Restaurant  59.329372  18.070265           20
# 91        French Restaurant  59.329319  18.070299           24
# 93  Scandinavian Restaurant  59.326110  18.073020            6
# 95  Scandinavian Restaurant  59.322391  18.074312           31
# 97                     Café  59.325061  18.070718            8
#
#            categories_new
# 1                    bars
# 3           american food
# 5                    None
# 6                    bars
# 7                    None
# 8                    None
# 9                    None
# 10                   None
# 14                   bars
# 16                   None
# 18                   None
# 19                   None
# 20       mex southam food
# 21                   None
# 22                   None
# 23                   None
# 24                   None
# 27                   None
# 28                   None
# 29                   None
# 30                   None
# 34                   None
# 37                   None
# 39                   None
# 41                   None
# 42                   None
# 43                  other
# 45           italian food
# 46                  other
# 48                   None
# 53                   None
# 55           italian food
# 60          american food
# 62           italian food
# 63                   None
# 65           italian food
# 66                   None
# 69  euro asia indian food
# 73                   None
# 75                   None
# 79                   None
# 83                   None
# 84          american food
# 91                   None
# 93                   None
# 95                   None
# 97                   None

# %% [markdown]
# ### Data Prep Part 4

# %%
# one hot encoding
stockholm_onehot = pd.get_dummies(stockholm_venues[['categories_new', 'total likes']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
stockholm_onehot['Name'] = stockholm_venues['name'] 

# move neighborhood column to the first column
fixed_columns = [stockholm_onehot.columns[-1]] + list(stockholm_onehot.columns[:-1])
stockholm_onehot = stockholm_onehot[fixed_columns]

stockholm_onehot.head()
# Out:
#                      Name  total likes  american food  bars  \
# 1                   Tweed          198              0     1
# 3  Barrels Burgers & Beer          448              1     0
# 5               Tradition           96              0     0
# 6             Corner Club          101              0     1
# 7            The Burgundy           40              0     0
#
#    euro asia indian food  italian food  mex southam food  other
# 1                      0             0                 0      0
# 3                      0             0                 0      0
# 5                      0             0                 0      0
# 6                      0             0                 0      0
# 7                      0             0                 0      0

# %%
cluster_df = stockholm_onehot.drop('Name', axis=1)

k_clusters = 4

# run k-means clustering
kmeans = KMeans(n_clusters=k_clusters, random_state=0).fit(cluster_df)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 2, 3, 3, 1, 3, 3, 3, 0, 2])

# %%
stockholm_venues['label'] = kmeans.labels_
stockholm_venues.head()
# Out:
#                      name                        id               categories  \
# 1                   Tweed  51434b65e4b00cf8d47795f1             Cocktail Bar
# 3  Barrels Burgers & Beer  549447fb498ed7d33f190dc2             Burger Joint
# 5               Tradition  534d0a34498ef782062ac89c  Scandinavian Restaurant
# 6             Corner Club  514c0868e4b07a3d6af2fca3             Cocktail Bar
# 7            The Burgundy  522784bb11d2164a04286219                 Wine Bar
#
#          lat        lng  total likes categories_new  label
# 1  59.324471  18.067696          198           bars      0
# 3  59.324685  18.068513          448  american food      2
# 5  59.325940  18.073710           96           None      3
# 6  59.323342  18.069431          101           bars      3
# 7  59.324434  18.068161           40           None      1

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(k_clusters)
ys = [i+x+(i*x)**2 for i in range(k_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(stockholm_venues['lat'], stockholm_venues['lng'], stockholm_venues['name'], stockholm_venues['label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
stockholm_venues.loc[stockholm_venues['label']==0]
# Out:
#                   name                        id               categories  \
# 1                Tweed  51434b65e4b00cf8d47795f1             Cocktail Bar
# 14          Pharmarium  51ccb742498e64f625f8ce57             Cocktail Bar
# 22  AIFUR | krog & bar  4ece875cb634dd298f5ea304  Scandinavian Restaurant
# 39     Under Kastanjen  4e198d6e18a8166f7396ffaa                     Café
# 42       Chokladkoppen  4adcdaebf964a520e35921e3                     Café
#
#           lat        lng  total likes categories_new  label
# 1   59.324471  18.067696          198           bars      0
# 14  59.324851  18.070891          178           bars      0
# 22  59.323097  18.071993          271           None      0
# 39  59.324794  18.072893          217           None      0
# 42  59.325020  18.070727          221           None      0

# %%
stockholm_venues.loc[stockholm_venues['label']==1]
# Out:
#                         name                        id  \
# 7               The Burgundy  522784bb11d2164a04286219
# 18               Matgatan 22  5729f110498e722233305953
# 21   Gaston - Wine Exploring  50c0cc79e4b0a80fdc3460df
# 23                Caffellini  4dc28371887770a6be00accd
# 27                    Kagges  58c90efcd243323eaf526efb
# 28  The Hairy Pig Restaurant  583875a96d632566864f820c
# 43               StikkiNikki  5731e745498ea03b4bfe08cb
# 45           Corvina Enoteca  51cb1bd3498e9a51850326c1
# 46                CitySallad  4d66061b48ee6ea85d166168
# 48                    Pastis  4b583319f964a520bf4d28e3
# 53       S:ta Clara Bierhaus  4c9cb5199975a143948034cf
# 55       Ristorante da Peppe  4b9a284ef964a520d7a135e3
# 60        Restaurang Brinken  55df60fd498e44d120c585cb
# 63                  Cafe Dox  4b4f5698f964a520f60127e3
# 65                 Rodolfino  4c62750486b6be9ae3138c34
# 66               Fem små hus  4b880a56f964a52018db31e3
# 69               Mogge Sushi  58ce88c415fb435821a3bd22
# 73            Magnus Ladulås  4adcdaf0f964a5203f5b21e3
# 75             Operakällaren  4adcdaf1f964a520965b21e3
# 79   Cultur Bar & Restaurant  511a7c7ae4b0707c95d29680
# 83       Sundbergs konditori  4bc576d4ccbcef3b3a93e6d2
# 84            Strömterrassen  4e14315c483bfda2e0a3715c
# 91                Brasseriet  553a646e498eb1b18ec63997
# 93                Myntkrogen  4c779735923ba1434b6e67e6
# 95          Zum Franziskaner  4adcdaebf964a520bc5921e3
# 97     Gamla Stan, Stockholm  5ad0514ce0c0c91d1b6da443
#
#                  categories        lat        lng  total likes  \
# 7                  Wine Bar  59.324434  18.068161           40
# 18        Polish Restaurant  59.324454  18.068671           27
# 21                 Wine Bar  59.323206  18.068640           69
# 23                     Café  59.323560  18.071373           33
# 27  Scandinavian Restaurant  59.323371  18.069441           14
# 28         Theme Restaurant  59.323738  18.068742           24
# 43           Ice Cream Shop  59.324699  18.068485           23
# 45       Italian Restaurant  59.323060  18.071104           30
# 46              Coffee Shop  59.326088  18.075268           14
# 48        French Restaurant  59.325093  18.073573           35
# 53        German Restaurant  59.323579  18.069006           34
# 55       Italian Restaurant  59.325878  18.067292           45
# 60               Restaurant  59.324204  18.068696            8
# 63                     Café  59.323921  18.069635           36
# 65       Italian Restaurant  59.325854  18.066945           53
# 66  Scandinavian Restaurant  59.325200  18.073931           60
# 69         Sushi Restaurant  59.324777  18.066829           14
# 73  Scandinavian Restaurant  59.323841  18.073726           19
# 75  Scandinavian Restaurant  59.329506  18.071626           64
# 79                 Wine Bar  59.323044  18.073469           57
# 83                     Café  59.322740  18.073046           60
# 84               Restaurant  59.329372  18.070265           20
# 91        French Restaurant  59.329319  18.070299           24
# 93  Scandinavian Restaurant  59.326110  18.073020            6
# 95  Scandinavian Restaurant  59.322391  18.074312           31
# 97                     Café  59.325061  18.070718            8
#
#            categories_new  label
# 7                    None      1
# 18                   None      1
# 21                   None      1
# 23                   None      1
# 27                   None      1
# 28                   None      1
# 43                  other      1
# 45           italian food      1
# 46                  other      1
# 48                   None      1
# 53                   None      1
# 55           italian food      1
# 60          american food      1
# 63                   None      1
# 65           italian food      1
# 66                   None      1
# 69  euro asia indian food      1
# 73                   None      1
# 75                   None      1
# 79                   None      1
# 83                   None      1
# 84          american food      1
# 91                   None      1
# 93                   None      1
# 95                   None      1
# 97                   None      1

# %%
stockholm_venues.loc[stockholm_venues['label']==2]
# Out:
#                                    name                        id  \
# 3                Barrels Burgers & Beer  549447fb498ed7d33f190dc2
# 16  Kungliga Slottet (Kungliga slottet)  4adcdaeef964a520c95a21e3
#
#       categories        lat        lng  total likes categories_new  label
# 3   Burger Joint  59.324685  18.068513          448  american food      2
# 16        Palace  59.326353  18.071140          497           None      2

# %%
stockholm_venues.loc[stockholm_venues['label']==3]
# Out:
#                         name                        id  \
# 5                  Tradition  534d0a34498ef782062ac89c
# 6                Corner Club  514c0868e4b07a3d6af2fca3
# 8              Slingerbulten  4ba0c261f964a520a77b37e3
# 9         The Hairy Pig Deli  537f7e60498e54e075c24907
# 10      19 Glas Bar & Matsal  4b9a5e8ff964a52072af35e3
# 19                   Kryp In  4c78322f93ef236a9772ab0f
# 20            Geronimo's FGT  550867d7498e86f0d8c9a61d
# 24            Ardbeg Embassy  4b63079df964a520945e2ae3
# 29  Café Schweizer Konditori  4d381d443ffba143aed55856
# 30             Café Stiernan  4c63fd4479d1e21eacddd915
# 34         Österlånggatan 17  4b180045f964a52039cb23e3
# 37               Kaffekoppen  4adcdaedf964a520555a21e3
# 41        Den Gyldene Freden  4adcdaf0f964a520655b21e3
# 62                Mr. French  51829a91498e80962fe0411e
#
#                  categories        lat        lng  total likes  \
# 5   Scandinavian Restaurant  59.325940  18.073710           96
# 6              Cocktail Bar  59.323342  18.069431          101
# 8   Scandinavian Restaurant  59.324376  18.068967          128
# 9             Deli / Bodega  59.325555  18.073958          100
# 10                 Wine Bar  59.324633  18.068670          109
# 19  Scandinavian Restaurant  59.324694  18.070059          120
# 20       Mexican Restaurant  59.325198  18.067725           75
# 24  Scandinavian Restaurant  59.323170  18.071904          144
# 29                     Café  59.326174  18.068824          104
# 30             Noodle House  59.323406  18.073597           75
# 34  Scandinavian Restaurant  59.325151  18.074016          112
# 37                     Café  59.325016  18.070693           99
# 41  Scandinavian Restaurant  59.323159  18.073512          114
# 62       Seafood Restaurant  59.323966  18.075842          152
#
#       categories_new  label
# 5               None      3
# 6               bars      3
# 8               None      3
# 9               None      3
# 10              None      3
# 19              None      3
# 20  mex southam food      3
# 24              None      3
# 29              None      3
# 30              None      3
# 34              None      3
# 37              None      3
# 41              None      3
# 62      italian food      3

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# Our analysis shows that although there is a great number of restaurants in Stockholm, there are pockets of low restaurant density fairly close to city center.Another borough was identified as potentially interesting but our attention was focused on offer a combination of popularity among tourists, closeness to city center, strong socio-economic dynamics *and* a number of pockets of low restaurant density.
#
# After directing our attention to this more narrow area of interest we first created a dense grid of location candidates (spaced 100m appart); those locations were then filtered so that those with more than two restaurants in radius of 250m and those with a restaurant closer than 400m were removed.
#
# Those location candidates were then clustered to create zones of interest which contain greatest number of location candidates. Addresses of centers of those zones were also generated using reverse geocoding to be used as markers/starting points for more detailed local analysis based on other factors.
#
# Result of all this is all zones containing largest number of potential new restaurant locations based on number of and distance to existing venues - both restaurants in general and Italian restaurants particularly. This, of course, does not imply that those zones are actually optimal locations for a new restaurant! Purpose of this analysis was to only provide info on areas close to Stockholm center but not crowded with existing restaurants - it is entirely possible that there is a very good reason for small number of restaurants in any of those areas, reasons which would make them unsuitable for a new restaurant regardless of lack of competition in the area. Recommended zones should therefore be considered only as a starting point for more detailed analysis which could eventually result in location which has not only no nearby competition but also other factors taken into account and all other relevant conditions met.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project was to identify Stockholm areas close to center with low number of restaurants in order to aid stakeholders in narrowing down the search for optimal location for a new restaurant. By calculating restaurant density distribution from Foursquare data we have first identified general boroughs that justify further analysis and then generated extensive collection of locations which satisfy some basic requirements regarding existing nearby restaurants. Clustering of those locations was then performed in order to create major zones of interest (containing greatest number of potential locations) and addresses of those zone centers were created to be used as starting points for final exploration by stakeholders.
#
# Final decission on optimal restaurant location will be made by stakeholders based on specific characteristics of neighborhoods and locations in every recommended zone, taking into consideration additional factors like attractiveness of each location (proximity to park or water), levels of noise / proximity to major roads, real estate availability, prices, social and economic dynamics of every neighborhood etc.
